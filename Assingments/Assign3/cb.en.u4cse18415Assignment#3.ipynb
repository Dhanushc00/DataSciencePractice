# %%
import numpy as np
import pandas as pd 
import seaborn as sns 
import matplotlib as mpl 
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
#1

# %%
iris=sns.load_dataset("iris")
plt.figure(figsize=(7,7))
sns.jointplot(x='sepal_length',y="sepal_width",data=iris,size=8)
plt.show()

# %%
#2

# %%
sns.FacetGrid(iris,hue='species',size=5)\
.map(plt.scatter,'sepal_length','sepal_width')\
.add_legend()

# %%
#3

# %%
sns.boxplot(x='species',y='sepal_length',data=iris)

# %%
#4

# %%
ax=sns.stripplot(x='species',y='sepal_length',data=iris,jitter=True,edgecolor='gray')

# %%
#5

# %%
ax=sns.boxplot(x='species',y='sepal_length',data=iris)
ax=sns.stripplot(x='species',y='sepal_length',data=iris,jitter=True,edgecolor='gray')

# %%
#6

# %%
sns.violinplot(x='species',y='sepal_length',data=iris,size=6)

# %%
#7

# %%
sns.pairplot(iris,hue='species',diag_kind="hist")

# %%
#8

# %%
plt.figure(figsize=(7,4))
sns.heatmap(iris.corr(),annot=True,cmap='summer')

# %%
#9

# %%
iris.hist(edgecolor='black', linewidth=1.2)
fig=plt.gcf()
fig.set_size_inches(12,6)
plt.show()

# %%
#10

# %%
sns.set(style="whitegrid")
fig=plt.gcf()
fig.set_size_inches(10,7)
fig = sns.swarmplot(x="species", y="sepal_length", data=iris)

# %%
plt.clf()
